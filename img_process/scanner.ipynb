# %%
import cv2
import numpy as np

# %%
win_name = 'scan'
src = cv2.imread('./dataset/KakaoTalk_20240420_113433452_01.jpg') # 이미지 파일 읽기
img = src.copy()

# %%
resize = cv2.resize(img, dsize=(0, 0), fx=0.2, fy=0.2, interpolation=cv2.INTER_AREA)
cv2.imshow("조절", resize)
cv2.waitKey(0) # param 시간동안 키보드 입력 대기 - 0 인경우 무한대기
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.GaussianBlur(gray, (3, 3), 0) # 이미지를 흐리게 처리함 (noise 제거를 위해 사용)
edged = cv2.Canny(gray, 75, 250) # edged를 검출하는 함수 (img, minVal, maxVal)
cv2.imshow('gray', edged)  # 윈도우 창에 보여주기 (윈도우창 title, 이미지)
cv2.waitKey(0) # param 시간동안 키보드 입력 대기 - 0 인경우 무한대기
cv2.destroyAllWindows()

# %%
# 컨투어 찾기
contours, hierarchy = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
len(contours)
# Out:
# 597

# %%
contours[0]
# Out:
# array([[[2561, 4023]],
#
#        [[2561, 4024]],
#
#        [[2562, 4025]],
#
#        [[2562, 4026]],
#
#        [[2563, 4026]],
#
#        [[2565, 4024]],
#
#        [[2565, 4023]]], dtype=int32)

# %%
draw = img.copy()
cv2.drawContours(draw,  contours, -1, (0, 255, 0))
cv2.imshow("contours", draw)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 외곽선 관련 함수
# - cv2.arcLength() : 외곽선의 길이를 반환
# - cv2.contourArea() : 외곽선이 감싸는 영역의 면적을 반환
# - cv2.boundingRect() : 주어진 점을 감싸는 최소 크기의 사각형(바운딩 박스)를 반환
# - cv2.minEnclosingCircle() : 주어진 점을 감싸는 최소 크기의 원을 반환
# - cv2.minAreaRect() : 주어진 점을 감싸는 최소 크기의 회전된 사각형을 반환
# - cv2.approxPolyDP() : 외곽선을 근사화(단순화)
# - cv2.fitEllipse() : 주어진 점에 적합한 타원을 반환
# - cv2.fitLine() : 주어진 점에 적합한 직선을 반환
# - cv2.isContourConvex() : 컨벡스인지를 검사
# - cv2.convexHull() : 주어진 점으로부터 컨벤스 헐을 반환
# - cv2.convexityDefects() : 주어진 점과 컨벡스 헐로부터 컨벡스 디펙트를 반환
#
# 참조 사이트
#  - https://deep-learning-study.tistory.com/232

# %%
# 컨투어들 중에 영역 크기 순으로 정렬
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:5]
for c in contours:
    peri = cv2.arcLength(c, True) # 외곽선 길이
    # print(peri)
    verticles = cv2.approxPolyDP(c, 0.02 * peri, True) # 외곽선 근사화
    if len(verticles) == 4 : 
        break
pts = verticles.reshape(4, 2) # 배열을 4 * 2 크기로 조정

# %%
print(pts)
print(pts.sum(axis=1))
print(np.diff(pts, axis=1))
print("좌상단", pts[np.argmin(pts.sum(axis=1))])
# Out:
# [[2485  582]
#  [ 516  589]
#  [ 346 3528]
#  [2663 3600]]
# [3067 1105 3874 6263]
# [[-1903]
#  [   73]
#  [ 3182]
#  [  937]]
# 좌상단 [516 589]

# %%
# 각각의 좌표 찾기
sumXY = pts.sum(axis=1)
diff = np.diff(pts, axis=1)

topLeft = pts[np.argmin(sumXY)]
bottomRight = pts[np.argmax(sumXY)]
topRight = pts[np.argmin(diff)]
bottomLeft = pts[np.argmax(diff)]

np.float32([topLeft, topRight, bottomRight, bottomLeft])
# Out:
# array([[ 516.,  589.],
#        [2485.,  582.],
#        [2663., 3600.],
#        [ 346., 3528.]], dtype=float32)

# %%
# 사진을 변환할 때 사용할 서류의 높이
widthTop = abs(topRight[0] - topLeft[0])
widthBottom = abs(bottomRight[0] - bottomLeft[0])
heightRight = abs(topRight[1] - bottomRight[1])
heightLeft = abs(topLeft[1] - bottomLeft[1])
print(widthBottom, widthTop, heightLeft, heightRight)

width = max([widthTop, widthBottom])
height = max([heightRight, heightLeft])
# Out:
# 2317 1969 2939 3018

# %%
pts1 = np.float32([topLeft, topRight, bottomRight, bottomLeft])
pts2 = np.float32([[0,0], [width, 0], [width, height], [0, height]])

# %%
matrix = cv2.getPerspectiveTransform(pts1, pts2) # 좌표를 변환하기 위해 사용할 변환행렬
result = cv2.warpPerspective(img, matrix, (width, height)) # 이미지 변환(변환행렬 적용)
cv2.imshow("result", result)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import easyocr

# %%
reader = easyocr.Reader(['ko', 'en'], gpu=True)
txt = reader.readtext(result)
print(txt)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[882, 66], [1454, 66], [1454, 115], [882, 115]], 'AeA proofs: manuscript no. wl27crires', 0.6290433014008742), ([[140, 154], [1153, 154], [1153, 216], [140, 216]], 'resolution When observing at high-resolution (R ~100000) the', 0.9450419374010174), ([[1180, 145], [2180, 145], [2180, 212], [1180, 212]], 'high-resolution study were detected to be strongly blue-shifted', 0.7034905818525103), ([[143, 197], [1153, 197], [1153, 257], [143, 257]], 'dynamics of the atmospheric material can be measured through', 0.6548361912684806), ([[1183, 188], [2176, 188], [2176, 252], [1183, 252]], "(by approximately 1Okm $-1) from the planet' s rest frame and", 0.4417425847404617), ([[144, 241], [1074, 241], [1074, 294], [144, 294]], 'Doppler shifts of the the signals caused by their relative', 0.7731315453403398), ([[1080, 255], [1145, 255], [1145, 282], [1080, 282]], 'mo-', 0.950320303440094), ([[1180, 231], [2105, 231], [2105, 293], [1180, 293]], 'the authors discussed the possibly of this signal being only', 0.5816051539247407), ([[146, 281], [1149, 281], [1149, 337], [146, 337]], 'tions towards the observer (Dang et al. 2018; Ehrenreich et al.', 0.6528760934106469), ([[1181, 277], [1886, 277], [1886, 332], [1181, 332]], 'of a broadened velocity signature , with other', 0.5216686330176448), ([[1969, 269], [2176, 269], [2176, 319], [1969, 319]], 'of the signal', 0.9997762445575517), ([[147, 322], [255, 322], [255, 366], [147, 366]], '2020).', 0.9517987570179474), ([[375, 326], [753, 326], [753, 374], [375, 374]], 'this benefit  high wind', 0.41518375494528686), ([[878, 329], [1148, 329], [1148, 370], [878, 370]], 'from jct strcams', 0.8943520160965267), ([[1182, 325], [1552, 325], [1552, 366], [1182, 366]], 'hidden within the noise', 0.8277567613541692), ([[149, 363], [661, 363], [661, 415], [149, 415]], 'and dayside-to-nightside winds', 0.8841719117494293), ([[667, 377], [706, 377], [706, 405], [667, 405]], 'as', 0.9187381816705043), ([[718, 371], [792, 371], [792, 408], [718, 408]], 'well', 0.9997374342571487), ([[797, 368], [1149, 368], [1149, 416], [797, 416]], 'as temperature differ-', 0.7781462456926229), ([[1182, 369], [1387, 369], [1387, 406], [1182, 406]], 'In this work', 0.840489239847132), ([[1395, 348], [2176, 348], [2176, 410], [1395, 410]], 'we used the CRyogenic InfraRed Echelle Spec-', 0.9431804971494434), ([[149, 407], [799, 407], [799, 448], [149, 448]], 'ences can be deduced from observed line', 0.9186632557166112), ([[798, 402], [1147, 402], [1147, 457], [798, 457]], 'broadening and asym-', 0.9838815606602714), ([[1181, 398], [1504, 398], [1504, 454], [1181, 454]], 'trograph (CRIRES+)', 0.998320698896219), ([[1516, 394], [1854, 394], [1854, 444], [1516, 444]], 'in the K band (1972', 0.6927029454964599), ([[1882, 386], [2173, 386], [2173, 435], [1882, 435]], '2452 nm) and in-', 0.7259028876922641), ([[153, 445], [1148, 445], [1148, 497], [153, 497]], 'metries (Prinoth et al. 2022; Keles 2021). In previous studies,', 0.6573010490360053), ([[1179, 424], [2177, 424], [2177, 496], [1179, 496]], 'dependently investigated the atmospheric composition and its', 0.9008040209240568), ([[151, 486], [1003, 486], [1003, 537], [151, 537]], 'signals from different parts of the planet atmosphere', 0.8922981899605861), ([[1008, 489], [1146, 489], [1146, 526], [1008, 526]], 'were of-', 0.9704464843718502), ([[1180, 482], [1609, 482], [1609, 539], [1180, 539]], 'atmospheric dynamics at a', 0.8215615901926707), ([[1744, 465], [2168, 465], [2168, 516], [1744, 516]], 'resolution of R ~140000.', 0.7517716991710904), ([[151, 528], [1147, 528], [1147, 576], [151, 576]], 'ten observed superimposed on each other and had to be disen-', 0.6793019674957007), ([[1185, 505], [2172, 505], [2172, 574], [1185, 574]], 'We report the detection of both H2O and CO using the cross-', 0.38394792842844616), ([[151, 562], [1150, 562], [1150, 617], [151, 617]], 'tangled through comparison with models containing combined', 0.6856128926570269), ([[1182, 567], [1354,  ...

# %%
for x in txt :
    print(x[1])
# Out:
# AeA proofs: manuscript no. wl27crires
# resolution When observing at high-resolution (R ~100000) the
# high-resolution study were detected to be strongly blue-shifted
# dynamics of the atmospheric material can be measured through
# (by approximately 1Okm $-1) from the planet' s rest frame and
# Doppler shifts of the the signals caused by their relative
# mo-
# the authors discussed the possibly of this signal being only
# tions towards the observer (Dang et al. 2018; Ehrenreich et al.
# of a broadened velocity signature , with other
# of the signal
# 2020).
# this benefit  high wind
# from jct strcams
# hidden within the noise
# and dayside-to-nightside winds
# as
# well
# as temperature differ-
# In this work
# we used the CRyogenic InfraRed Echelle Spec-
# ences can be deduced from observed line
# broadening and asym-
# trograph (CRIRES+)
# in the K band (1972
# 2452 nm) and in-
# metries (Prinoth et al. 2022; Keles 2021). In previous studies,
# dependently investigated the atmospheric composition and its
# signals from different parts of the planet atmosphere
# were of-
# atmospheric dynamics at a
# resolution of R ~140000.
# ten observed superimposed on each other and had to be disen-
# We report the detection of both H2O and CO using the cross-
# tangled through comparison with models containing combined
# correlation
# method.
# We
# further   report
# the  detection
# of
# two
# absorption features of different
# (Gandhi et al. 2022) and
# in the velocity
# for each of these
# species, located
# comparing differences between ingress and egress lines shapes
# at
# approximately
# 소
# 8 km
# s-1
# These peaks remained resolved
# (Scidel et al. 2023; Louden & Wheatley 2015)
# One advantage
# mhropghout the entire duration of the planetary transit We found
# that was used to disentangle signals in the time domain was that
# that these two
# peaks can be
# explained
# as
# representing chehige
# very close-in planets with very short orbital periods (~ 1-2 days)
# nads stemming from the two limbs of the planet; We used
# resolved signals to retrieve the
# atmospheric
# undergo significant changes in projected viewing angle between
# spectroscopically
# regions of the morning limb
# transit ingress and egress (Gandhi et al. 2022; Ehrenreich et al.
# properties ofirhelinno equatoriaf regions [fithe wm'
# a
# Bayesian
# 2020; Seidel et al. 2023; Prinoth et al. 2023). This effect,
# and the evening limb; as well as
# two-
# at
# aarieval Evamegork fhe retrieval is utilizing a simplified
# ever; becomes progressively less pronounced for planets
# larger
# model,  which incorporates the free-
# distances from their host stars,i.e. longer orbital periods.
# dimensional atmospheric
# conditions at differ-
# Here
# we studied the transmission spectrum of the hot Jupiter
# dom of varying dynaifickeand amospherichcondjytioninag dinew
# exoplanet WASP-127b, which orbits its G-type host star
# on
# a
# ent latitudes and longitudes of the planet,
# atmospheres.
# 4.18
# orbit (Lam et al. 2017). The planet has one of the low
# pathway for probing inhomogeneities inhexopfenettitmno
# are
# de-
# est densities ever recorded for an exoplanet (p
# =
# 0.07 t
# O.O1pJp;
# Our work is structured
# as follows.
# The
# -processing
# Lam et al. 2017) which, in combination with its favorable star-
# scribed in Sect
# 2
# 'The daa teductioigand preprocoeging such
# planet radius ratio, makes it a
# target for atmospheric stud-
#   ,he removal of steltmosndceiluric signafs dsdrsccif
# in Sect. 4
# ies. The first indication of a feature-rich transmission spectrum
# 3. The detection of atmospheric species is
# in Sect. 4.1 and the
# on this planet was obtained at low resolution with the Andalu-
# with details on the model calculation given
# 4.2. The results of
# cia Faint Object Spectrograph and Camera (ALFOSC) mounted
# cross-correlation ianalysis describeden aScctisc-asschinSactoas
# on the 2.5m Nordic Optical Telescope (NOT) at ORM obser-
# the cross-correlation analysis are given
# discuss the interpreta-
# vatory (Palle et al. 2017)
# These findings were later confirmed
# 4,3 and 4.4, respectively In Sect. 4.5 we
# of the two dimen-
# with higher precision using the OSIRIS instrument at the IOm-
# tion of the double
# signalesThocsetuBof the >e donurs
# GranTeCan (Chen et al. 2018), showing not only sodium and
# sional
# atmospheric retrieval is described
# in Sect. 5.4. Finally;
# but also a tentative detection of lithium in
# of the retrieval are
# provided and discussed
# potassium absorption
# res-
# give conclusions about our work in Sect 6
# the planet However; follow-uP studies of the planet at high
# olution in the optical wavelength range only measured
# a weak
# signal for sodium with ESPRESSO at the 8m-VLT (Allart et al:
# 2. Observations
# 2020) and HARPS (Seidel et al. 2020), the latter being compati-
# b during a transit
# ble with a non-detection. Using the Rossiter-McLaughlin effect,
# We observed the extrasolar planet WASP-127
# observations of the planet during transit re-
# eventie. when the planet passed in front Ofits host star in our
# 'esehiqlatresolution
# is orbiting its host on
# a
# misaligned orbit
# line of sight,
# the night 24-25 March 2022 in the K band us-
# Valed trat UhoPtaneritorbiting0요2)c
# The
# atmosphere and or-
# the
# infrared spectrograph CRIRES
# mounted
# at
# bAtllarr efuatheozonstrasteeGby successfuf eclipse measurements
# the Nasmyth B focus of the 8m UT3 telescope at the Very Large
# bittwee
# which determined the planet' s dayside tempera-
# Telescope Facility of the European Southern Observatory (Dorn
# ture
# as
# Spitzer;
# ~
# 1400 K (1454+43 K, 1373+40 K
# at at 3.6pm and
# et al. 2023). The observation lasted for 6.6 hours (00.22 UT
# Wallack.t al: 2021).Low-resolution space-
# 07.03 UT) and covered the whole transit event as well as a com-
# basemspesnectoelyobainact Gr ah2G banowitsqhotiorgBaGn
# parable amount of pre- and
# transit baseline (Fig.
# 1 a)
# The
# spectroscopy
# the Hubble Space telescope (HST) led to
# a
# detection of water
# exposure time of 240 $
# was
# purposefully chosen short enough to
# in the planet' $ transmission spectrum (Skaf et al: 2020; Spake
# avoid the planet signal spreading over several detector pixels duc
# et al. 2021).
# An
# atmospheric retrieval study combining the HST
# to the Doppler shift caused by the planet' s orbital motion
# For
# and Spitzer transit data led to conflicting carbon-to-oxygen ratios
# comparison, the projected orbital velocity of this planet changes
# (CIO) depending on whether chemical
# equilibrium
# or free chem-
# by approximately
# 1
# km
# s-1
# every 456 $
# during transit. In total
# istry assumptions were adopted (leading to values of CIO
# ~
# 0.8
# we obtained 98 spectra, 62 of them in transit, including ingress
# and CIO
# ~
# 0.0 respectively; Spake et
# 2021). This degener-
# and egress, ie. between first and fourth contact (T1-T4); 50 of
# acy
# was
# seemingly solved through recent high-resolution ob-
# these between second and third contact, excluding ingress and
# servations of this target over
# a
# large wavelength range in the
# egress (T2-T3) (see Fig. 1 a). The airmass at the start of the ob-
# near-infrared
# 980
# 2500 nm) using the SPIRou spectrograph;
# servation was 1.5, reached a minimum of 1.07
# during the transit
# which yielded a detection of water (H2O) and hydroxyl (OH)
# and then rose
# to 1.9 towards the end of the observation
# but no carbon monoxide (CO) The non-detection of CO led to
# in the post-transit coverage. The signal-to-noise ratio (S/N) per
# strong upper limits on the CO abundance (logio(CO)
# <
# -4.0)
# pixel fluctuated between 57-73. The progression Of the airmass
# and favored
# d
# disequilibrium case with a low CIO ratio for this
# and mean SIN over the course of the
# observing night are shown
# planet in the joint retrieval of SPIRou
# +
# HST
# +
# Spitzer data
# in Fig. 1 b and c, respectively. We used a slit width of 0.2" and
# (Boucher et al. 2023). The H2o and
# OH signals found in this
# the K band setting K2148, which covers the wavelength range
# Article number; page 2 of 18
# part
# parts
# Using
# specds
# spectral
# profile
# regions
# peaks
# how-
# day
# such
# prime
# peaked
# we
# on
# upgraded
# ing
# post-
# al.
# again
